# %% [markdown]
# # Preface

# %% [markdown]
# ```{figure} pict/preface.png
# ---
# scale: 30%
# align: right
# ---
#
# ```
#
# This book is designed to make selected passages from the Risale-i Nur collection accessible, engaging, and suitable for both individual study and group discussion.
#
# Each section of this book is built around a carefully selected one-page article, referred to as the Main Passage. The goal is to help readers develop a deeper understanding of the ideas presented in the Risale-i Nur while encouraging reflection, discussion, and practical application.
#
# Every section includes:
#
# - Reading objectives to guide learning
# - Background information to provide context
# - The Main Passage, along with a link to its original ODF source
# - A summary of the passage
# - Brief explanations of the sections that come before and after the Main Passage
# - Reading comprehension questions
# - Critical thinking questions
# - A glossary of key vocabulary words found in the passage
#
# This book is designed to be flexible and can be used in different ways. It may be read independently at one's own pace or studied collaboratively in a book club, classroom, or study circle.
#
# For group study, participants may first read the one-page Main Passage individually and then come together to discuss its ideas, answer questions, and reflect on its relevance to their own lives. This approach encourages active participation and thoughtful conversation while making the teachings of the Risale-i Nur more approachable for readers of all backgrounds.
#
# Repeated reading, reflection, and discussion are central to this learning process. Rather than attempting to cover large portions of text at once, this book invites readers to slow down, focus on one passage at a time, and gradually build a deeper understanding of the timeless themes of faith, purpose, responsibility, and spiritual growth found throughout the Risale-i Nur collection.
#
# It is our hope that this resource will serve as a practical companion for anyone seeking to study, teach, discuss, and reflect upon the enduring wisdom of the Risale-i Nur.
